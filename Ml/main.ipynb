# %%
# !nvidia-smi
# Out:
# Sun Mar 22 19:41:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0             33W /   70W |     155MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install unsloth

# %%
import json
from datasets import Dataset

with open('tdata', 'r') as f:
    data = json.load(f)

    tuning_exmaples = []

    for exnample in data:
        tuning_exmaples.append({
            'input': example['input'],
            'output': example['output']
        })
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3823/3538626811.py in <cell line: 0>()
#       2 from datasets import Dataset
#       3
# ----> 4 with open('tdata', 'r') as f:
#       5     data = json.load(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tdata'

# %%
import json
from datasets import Dataset
from unsloth import FastLanguageModel

# Load your raw examples
with open("tdata.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Load model + tokenizer first
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Qwen2.5-7B-Instruct-bnb-4bit",  # example
    max_seq_length=4096,
    load_in_4bit=True,
)

training_texts = []

for example in data:
    text = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False,
    )
    training_texts.append(text)

dataset = Dataset.from_dict({"text": training_texts})

print(dataset[0]["text"][:1500])
print("Total examples:", len(dataset))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3823/2917809159.py in <cell line: 0>()
#       4
#       5 # Load your raw examples
# ----> 6 with open("tdata.json", "r", encoding="utf-8") as f:
#       7     data = json.load(f)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tdata.json'

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'unsloth_compiled_cache', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded.keys())
# Out:
#      <input type="file" id="files-3e250469-2670-411a-9b79-192c21d0467c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e250469-2670-411a-9b79-192c21d0467c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
